# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !cp /content/drive/MyDrive/projected_cleaned_vehicles.csv /content/projected_cleaned_vehicles.csv

# %%
projected_data = pd.read_csv("/content/projected_cleaned_vehicles.csv")

# %%
projected_data.head()
# Out:
#        feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0 -128000.000046   8.341525  -5.410019   7.925090  -1.895138   0.685215
# 1  -68696.000053   9.773459  -8.032196   5.458732  -0.976501   0.056125
# 2  -29499.000032   5.930350  -6.454539   4.964650  -1.675067  -0.353644
# 3  -43000.000015   2.788633  -5.414537   7.862467  -0.966658  -0.268824
# 4  -17302.000032   5.996607  -6.114440   4.903305  -0.740528  -0.490511
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_843  feature_844  \
# 0   2.054979   0.445602  -0.721441  -0.441300  ...    -0.000135    -0.010270
# 1   1.407650   1.212764  -0.691593  -0.486836  ...    -0.000636    -0.009868
# 2   1.385933   0.937556  -0.355378  -0.703055  ...    -0.000561    -0.010271
# 3   2.323440   0.506191  -0.635604  -0.696300  ...    -0.001108    -0.009775
# 4   1.465502   0.799584  -0.302888  -0.704587  ...    -0.000674    -0.010326
#
#    feature_845  feature_846  feature_847  feature_848  feature_849  \
# ...

# %%
X=projected_data.iloc[:, :-1]
X
# Out:
#             feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0      -128000.000046   8.341525  -5.410019   7.925090  -1.895138   0.685215
# 1       -68696.000053   9.773459  -8.032196   5.458732  -0.976501   0.056125
# 2       -29499.000032   5.930350  -6.454539   4.964650  -1.675067  -0.353644
# 3       -43000.000015   2.788633  -5.414537   7.862467  -0.966658  -0.268824
# 4       -17302.000032   5.996607  -6.114440   4.903305  -0.740528  -0.490511
# ...               ...        ...        ...        ...        ...        ...
# 144012   -7701.000011   2.057456  -5.997226   4.686649  -1.649114   1.415676
# 144013  -41664.000027   4.910868  -8.120377   5.439886  -1.042424   0.246692
# 144014  -55612.000032   5.838168  -7.828113   5.352915  -1.043093   1.122725
# 144015  -30814.000021   3.911160  -5.761534   4.840423  -0.925957   0.800176
# 144016  -30112.000021   3.929224  -5.806683   4.701934  -1.697959   1.682547
#
# ...

# %%
y=projected_data.iloc[:, -1]
y
# Out:
# 0         15000
# 1         27990
# 2         34590
# 3         35000
# 4         29990
#           ...
# 144012    48590
# 144013    39990
# 144014    32990
# 144015    33590
# 144016    28990
# Name: price, Length: 144017, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.30, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_train
# Out:
# array([[-6.71647246e-03,  3.53514599e-01, -1.06404801e+00, ...,
#         -4.31779612e-13,  2.89579135e-01,  3.38756800e-14],
#        [ 2.53796586e-01, -3.22383267e-01,  1.48219933e+00, ...,
#          2.82031343e-12, -1.38700196e+00,  7.25475235e-13],
#        [-3.48544397e-01, -2.88781892e-01,  8.98292937e-01, ...,
#          4.73024397e-13, -2.81909448e-01, -2.55247212e-14],
#        ...,
#        [-2.82318978e-01,  3.14411156e-01,  2.64770216e-01, ...,
#          9.85017623e-13, -6.14675566e-01,  3.79172388e-13],
#        [ 3.12270396e-01, -8.11375580e-01,  9.22386545e-01, ...,
#          1.21902488e-12, -4.20746010e-01,  3.05172554e-13],
#        [-2.54864812e-01, -1.77909882e-01, -1.82060634e-01, ...,
#          2.51382248e-12, -9.73011922e-01,  6.24573310e-13]])

# %%
X_test=scaler.transform(X_test)
X_test
# Out:
# array([[-2.81975636e-01,  1.17259570e-01,  9.62956171e-01, ...,
#         -1.90457372e-12,  1.91867463e+00, -8.70126887e-13],
#        [ 1.03157418e-01, -5.32784136e-01, -2.68832794e-01, ...,
#          1.85722271e-12, -6.84360348e-01,  4.67872269e-13],
#        [-1.83797388e-01,  2.40022626e-02,  8.40187999e-01, ...,
#          1.89141758e-12, -2.27121026e-01,  3.85372290e-13],
#        ...,
#        [-1.71930075e-01,  9.34124636e-01, -4.16951473e-01, ...,
#         -3.92998134e-12,  1.51388406e+00, -8.83827733e-13],
#        [ 4.84711790e-01,  9.07284647e-01,  2.30467999e-01, ...,
#         -2.64538391e-12,  1.88680528e+00, -8.03926370e-13],
#        [ 4.94551842e-02, -5.33747164e-01, -1.23487942e+00, ...,
#          2.76514922e-13, -4.60028928e-01,  2.44474579e-13]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
regression = LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
mae=cross_val_score(regression,X_train,y_train,scoring='neg_mean_absolute_error',cv=10)

# %%
np.mean(mae)
# Out:
# -423068.39853418246
